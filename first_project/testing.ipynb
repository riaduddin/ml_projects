# %%
import numpy
from sklearn.datasets import load_svmlight_file

# %%
# Load the training set for Fold 1
data_path = "Letor/OHSUMED/Data/Fold1/trainingset.txt"

# query_id=True extracts the 'qid' values into the 'query_id' variable
X, y, query_id = load_svmlight_file(data_path, query_id=True)

print(f"Number of samples: {X.shape[0]}")
print(f"Number of features: {X.shape[1]}")
print(f"Unique Query IDs: {len(set(query_id))}")
# Out:
# Number of samples: 9219
# Number of features: 25
# Unique Query IDs: 63

# %%
import pandas as pd

def load_letor_to_dataframe(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.split('#')[0].strip().split()
            label = int(parts[0])
            qid = parts[1].split(':')[1]
            features = {p.split(':')[0]: float(p.split(':')[1]) for p in parts[2:]}
            
            row = {'label': label, 'qid': qid}
            row.update(features)
            data.append(row)
            
    return pd.DataFrame(data)

df = load_letor_to_dataframe("Letor/OHSUMED/Data/Fold1/trainingset.txt")
df.head()
# Out:
#    label qid    1         2         3         4          5          6  \
# 0      2   1  3.0  2.079442  0.272727  0.261034  37.330565  11.431241
# 1      0   1  3.0  2.079442  0.428571  0.400594  37.330565  11.431241
# 2      2   1  0.0  0.000000  0.000000  0.000000  37.330565  11.431241
# 3      2   1  4.0  2.772589  0.333333  0.320171  37.330565  11.431241
# 4      0   1  0.0  0.000000  0.000000  0.000000  37.330565  11.431241
#
#           7         8  ...        16         17        18         19  \
# 0  37.29975  1.138657  ...  9.340024  24.808785  0.393091  57.416517
# 1  37.29975  1.814480  ...  9.340024  24.808785  0.349205  43.240626
# 2  37.29975  0.000000  ...  9.340024  24.808785  0.240319  25.816989
# 3  37.29975  1.260808  ...  9.340024  24.808785  0.111496  10.092426
# 4  37.29975  0.000000  ...  9.340024  24.808785  0.182104  23.546296
#
#          20       21        22       23       24       25
# 0  3.294893  25.0231  3.219799 -3.87098 -3.90273 -3.87512
# 1  2.654724  23.4903  3.156588 -3.96838 -4.00865 -3.98670
# 2  1.551342  15.8650  2.764115 -4.28166 -4.33313 -4.44161
# 3  0.649758  14.2778  2.658706 -4.77772 -4.73563 -4.86759
# 4  1.621393  15.2764  2.726309 -4.43073 -4.45985 -4.57053
#
# [5 rows x 27 columns]
